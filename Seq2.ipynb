# %%
from urllib.request import urlretrieve
from pyopenms import *

exp = MSExperiment()
MzMLFile().load("4.mzML", exp)

protein_ids = []
peptide_ids = []
SimpleSearchEngineAlgorithm().search("4.mzML",
                                     "uniprot-yourlist_M202201076320BA52A5CE8FCD097CB85A53697A353B944FQ.fasta", protein_ids,
                                     peptide_ids)
spectra = exp.getSpectra()

from matplotlib import pyplot as plt


def mirror_plot(obs_mz, obs_int, theo_mz, theo_int, title):
    obs_int = [element / max(obs_int) for element in obs_int]  # relative intenstiy
    theo_int = [element * -1 for element in theo_int]  # invert the intensity for the mirror plot
    plt.figure(figsize=(12, 8))
    plt.bar(obs_mz, obs_int, width=3.0)
    plt.bar(theo_mz, theo_int, width=3.0)
    plt.title(title)
    annot = thspec.getStringDataArrays()[0]
    bars = plt.bar(obs_mz, obs_int, snap=False)  # snap ensures that all bars are rendered
    idx = 0
    for rect in bars:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width() / 2.0, height, annot[idx].decode(), ha='center', va='bottom',
                 rotation=90)
        idx += 1
    plt.ylim(top=1.2)

    plt.ylabel('intensity')
    plt.xlabel('m/z')
    plt.show()


for peptide_id in peptide_ids:
    # Peptide identification values
    print(35 * "=")
    print("Peptide ID m/z:", peptide_id.getMZ())
    print("Peptide ID rt:", peptide_id.getRT())
    print("Peptide scan index:", peptide_id.getMetaValue("scan_index"))
    print("Peptide scan name:", peptide_id.getMetaValue("scan_index"))
    print("Peptide ID score type:", peptide_id.getScoreType())
    # PeptideHits
    for hit in peptide_id.getHits():
        print(" - Peptide hit rank:", hit.getRank())
        print(" - Peptide hit charge:", hit.getCharge())
        print(" - Peptide hit sequence:", hit.getSequence())
        mz = hit.getSequence().getMonoWeight(Residue.ResidueType.Full, hit.getCharge()) / hit.getCharge()
        print(" - Peptide hit monoisotopic m/z:", mz)
        print(" - Peptide ppm error:", abs(mz - peptide_id.getMZ()) / mz * 10 ** 6)
        print(" - Peptide hit score:", hit.getScore())
        tsg = TheoreticalSpectrumGenerator()
        thspec = MSSpectrum()
        p = Param()
        p.setValue("add_y_ions", "true")
        p.setValue("add_b_ions", "true")
        p.setValue("add_metainfo", "true")
        tsg.setParameters(p)
        a = str(hit.getSequence())
        peptide = AASequence.fromString(a)
        tsg.getSpectrum(thspec, peptide, 1, 2)

################################################################################################
        #allignment code
        exp_spec = exp.getSpectrum(peptide_id.getMetaValue("scan_index"))
        alignment = []
        spa = SpectrumAlignment()
        p = spa.getParameters()
        p.setValue("tolerance", 0.5)
        p.setValue("is_relative_tolerance", "false")
        spa.setParameters(p)
        spa.getSpectrumAlignment(alignment, thspec, exp_spec)
        print("Number of matched peaks: " + str(len(alignment)))
        print("ion\ttheo. m/z\tobserved m/z")

        for theo_idx, obs_idx in alignment:
            ion_name = thspec.getStringDataArrays()[0][theo_idx].decode()
            ion_charge = thspec.getIntegerDataArrays()[0][theo_idx]
            print(ion_name + "\t" + str(ion_charge) + "\t" + str(thspec[theo_idx].getMZ()) + "\t" + str(
                exp_spec[obs_idx].getMZ()))

        theo_mz, theo_int, obs_mz, obs_int = [], [], [], []
        b = str(peptide_id.getMetaValue("scan_index"))
        title = a + "  " + b
        for theo_idx, obs_idx in alignment:
            theo_mz.append(thspec[theo_idx].getMZ())
            theo_int.append(thspec[theo_idx].getIntensity())
            obs_mz.append(exp_spec[obs_idx].getMZ())
            obs_int.append(exp_spec[obs_idx].getIntensity())
        mirror_plot(obs_mz, obs_int, theo_mz, theo_int, title)
# Out:
# ===================================
# Peptide ID m/z: 423.227416992188
# Peptide ID rt: 995.00816614398
# Peptide scan index: 643
# Peptide scan name: 643
# Peptide ID score type: hyperscore
#  - Peptide hit rank: 1
#  - Peptide hit charge: 2
#  - Peptide hit sequence: THGVFQR
#  - Peptide hit monoisotopic m/z: 422.72484587592106
#  - Peptide ppm error: 1188.8847347630592
#  - Peptide hit score: 0.2117382287979126
# Number of matched peaks: 5
# ion	theo. m/z	observed m/z
# b4+	1	395.203746296171	395.25897216796875
# y3+	1	450.2459454556711	449.891357421875
# b5+	1	542.272160583271	541.8750610351562
# y4+	1	549.3143597427711	549.7988891601562
# y6+	1	743.3947360617711	743.1920776367188
# ===================================
# Peptide ID m/z: 470.721771240234
# Peptide ID rt: 1385.1200982400198
# Peptide scan index: 5205
# Peptide scan name: 5205
# Peptide ID score type: hyperscore
#  - Peptide hit rank: 1
#  - Peptide hit charge: 2
#  - Peptide hit sequence: TLDSYADR
#  - Peptide hit monoisotopic m/z: 470.722166939721
#  - Peptide ppm error: 0.8406221648184736
#  - Peptide hit score: 0.21364060044288635
# Number of matched peaks: 1
# ion	theo. m/z	observed m/z
# b3+	1	330.16596420047097	330.0598449707031
# ===================================
# Peptide ID m/z: 470.722198486328
# Peptide ID rt: 1387.5853060480201
# Peptide scan index: 5216
# Peptide scan name: 5216
# Peptide ID score type: hyperscore
#  - Peptide hit rank: 1
#  - Peptide hit charge: 2
#  - Peptide hit sequence: TLDSYADR
#  - Peptide hit monoisotopic m/z: 470.722166939721
#  - Peptide ppm error: 0.06701746645669582
#  - Peptide hit score: 0.20349502563476562
# Number of matched peaks: 0
# ion	theo. m/z	observed m/z
# ===================================
# Peptide ID m/z: 438.245391845703
# Peptide ID rt: 1447.91851961598
# Peptide scan index: 5535
# Peptide scan name: 5535
# Peptide ID score type: hyperscore
#  - Peptide hit rank: 1
#  - Peptide hit charge: 2
#  - Peptide hit sequence: IAIM(Oxidation)GAAGR
#  - Peptide hit monoisotopic m/z: 438.24201438447096
#  - Peptide ppm error: 7.706840332943207
#  - Peptide hit score: 0.3953770399093628
# Number of matched peaks: 0
# ion	theo. m/z	observed m/z
# ===================================
# Peptide ID m/z: 591.298645019531
# Peptide ID rt: 1500.219245616
# Peptide scan index: 5774
# Peptide scan name: 5774
# Peptide ID score type: hyperscore
#  - Peptide hit rank: 1
#  - Peptide hit charge: 2
#  - Peptide hit sequence: YDMQDVLGLK
#  - Peptide hit monoisotopic m/z: 591.297184671571
#  - Peptide ppm error: 2.469736027606195
#  - Peptide hit score: 0.08083836734294891
# Number of matched peaks: 1
# ion	theo. m/z	observed m/z
# y1+	1	147.112804913371	147.11305236816406
# ===================================
# Peptide ID m/z: 423.227142333984
# Peptide ID rt: 1510.50972168
# Peptide scan index: 5816
# Peptide scan name: 5816
# Peptide ID score type: hyperscore
#  - Peptide hit rank: 1
#  - Peptide hit charge: 2
#  - Peptide hit sequence: THGVFQR
#  - Peptide hit monoisotopic m/z: 422.72484587592106
#  - Peptide ppm error: 1188.2350019481703
#  - Peptide hit score: 0.614918053150177
# Number of matched peaks: 1
# ion	theo. m/z	observed m/z
# y2++	2	152.09240381767103	152.05654907226562
# ===================================
# Peptide ID m/z: 514.525390625
# Peptide ID rt: 1557.61890006402
# Peptide scan index: 5997
# Peptide scan name: 5997
# Peptide ID score type: hyperscore
#  - Peptide hit rank: 1
#  - Peptide hit charge: 4
#  - Peptide hit sequence: VDAPSGTALMLGEAVAEPLGR
#  - Peptide hit monoisotopic m/z: 514.2701268295712
#  - Peptide ppm error: 496.3613130759197
#  - Peptide hit score: 0.03874072805047035
# Number of matched peaks: 1
# ion	theo. m/z	observed m/z
